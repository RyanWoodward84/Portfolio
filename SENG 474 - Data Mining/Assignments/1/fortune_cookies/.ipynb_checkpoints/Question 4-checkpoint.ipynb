# %% [markdown]
# # Question 4: Implementing a Multinomial Naive Bayes Classifier

# %% [markdown]
# We need to implement the multinomial naive bayes training algorithm

# %% [markdown]
# 1) We need to extract the vocabulary from the traindata.txt

# %%
import pandas as pd

data = pd.read_csv('traindata.txt', sep='\t', header = None)
data.head()
# Out:
#                                                    0
# 0  a new voyage will fill your life with untold m...
# 1              you are on the verge of something big
# 2    a pleasant experience is ahead don't pass it by
# 3       a thrilling time is in your immediate future
# 4  a heavy burden is lifted with a phone message ...

# %%
for i in range(df.shape[0]):
    test = data.iloc[i,0]
    trainingData.append(test.split())

trainingData
# Out:
# [['a',
#   'new',
#   'voyage',
#   'will',
#   'fill',
#   'your',
#   'life',
#   'with',
#   'untold',
#   'memories'],
#  ['you', 'are', 'on', 'the', 'verge', 'of', 'something', 'big'],
#  ['a', 'pleasant', 'experience', 'is', 'ahead', "don't", 'pass', 'it', 'by'],
#  ['a', 'thrilling', 'time', 'is', 'in', 'your', 'immediate', 'future'],
#  ['a',
#   'heavy',
#   'burden',
#   'is',
#   'lifted',
#   'with',
#   'a',
#   'phone',
#   'message',
#   'or',
#   'letter'],
#  ['you', 'are', 'going', 'to', 'have', 'a', 'pleasant', 'experience'],
#  ['everywhere',
#   'you',
#   'choose',
#   'to',
#   'go',
#   'friendly',
#   'faces',
#   'will',
#   'greet',
#   'you'],
#  ['you',
#   'will',
#   'become',
#   'a',
#   'great',
#   'philanthropist',
#   'in',
#   'your',
#   'later',
#   'years'],
#  ['you',
#   'will',
#   'attract',
#   'cultured',
#   'and',
#   'artistic',
#   'people',
#   'to',
#   'your',
#   'home'],
#  ['although',
#   'it',
#   'feels',
#   'like',
#   'a',
#   'roller',
#   'coaster',
#   'now',
#   'life',
#   'will',
#   'calm',
#   'down'],
#  ['happier',
#   'days',
#   'are',
#   'definitely',
#   'ahead',
#   'for',
#   'you',
#   'struggle',
#   'has',
#   'ended'],
#  ['you',
#   'are',
#   'going',
#   'to',
#   'have',
#   'a',
#   'very',
#   'comfortable',
#   'old',
#   'age'],
#  ['you',
#   'will',
#   'take',
#   'a',
#   'chance',
#   'in',
#   'something',
#   'in',
#   'the',
#   'near',
#   'future'],
#  ['you',
#   'may',
#   'attend',
#   'a',
#   'party',
#   'where',
#   'strange',
#   'customs',
#   'prevail'],
#  ['you',
#   'will',
#   'always',
#   'possess',
#   'a',
#   'charm',
#   'and',
#   'sense',
#   'of',
#   'humor',
#   'that',
#   'attracts',
#   'others'],
#  ['a',
#   'new',
#   'voyage',
#   'will',
#   'fill',
#   'your',
#   'life',
#   'with',
#   'untold',
#   'memories'],
#  ['you', 'are', 'on', 'the', 'verge', 'of', 'something', 'big'],
#  ['a', 'pleasant', 'experience', 'is', 'ahead', "don't", 'pass', 'it', 'by'],
#  ['a', 'thrilling', 'time', 'is', 'in', 'your', 'immediate', 'future'],
#  ['a',
#   'heavy',
#   'burden',
#   'is',
#   'lifted',
#   'with',
#   'a',
#   'phone',
#   'message',
#   'or',
#   'letter'],
#  ['you', 'are', 'going', 'to', 'have', 'a', 'pleasant', 'experience'],
#  ['everywhere',
#   'you',
#   'choose',
#   'to',
#   'go',
#   'friendly',
#   'faces',
#   'will',
#   'greet',
#   'you'],
#  ['you',
#   'will',
#   'become',
#   'a',
#   'great',
#   'philanthropist',
#   'in',
#   'your',
#   'later',
#   'years'],
#  ['you',
#   'will',
#   'attract',
#   'cultured',
#   'and',
#   'artistic',
#   'people',
#   'to',
#   'your',
#   'home'],
#  ['although',
#   'it',
#   'feels',
#   'like',
#   'a',
#   'roller',
#   'coaster',
#   'now',
#   'life',
#   'will',
#   'calm',
#   'down'],
#  ['happier',
#   'days',
#   'are',
#   'definitely',
#   'ahead',
#   'for',
#   'you',
#   'struggle',
#   'has',
#   'ended'],
#  ['you',
#   'are',
#   'going',
#   'to',
#   'have',
#   'a',
#   'very',
#   'comfortable',
#   'old',
#   'age'],
#  ['you',
#   'will',
#   'take',
#   'a',
#   'chance',
#   'in',
#   'something',
#   'in',
#   'the',
#   'near',
#   'future'],
#  ['you',
#   'may',
#   'attend',
#   'a',
#   'party',
#   'where',
#   'strange',
#   'customs',
#   'prevail'],
#  ['you',
#   'will',
#   'always',
#   'possess',
#   'a',
#   'charm',
#   'and',
#   'sense',
#   'of',
#   'humor',
#   'that',
#   'attracts',
#   'others']]

# %%
from pandas import DataFrame 
DataFrame.from_records(trainingData)
# Out:
#             0          1           2           3       4               5   \
# 0            a        new      voyage        will    fill            your
# 1          you        are          on         the   verge              of
# 2            a   pleasant  experience          is   ahead           don't
# 3            a  thrilling        time          is      in            your
# 4            a      heavy      burden          is  lifted            with
# 5          you        are       going          to    have               a
# 6   everywhere        you      choose          to      go        friendly
# 7          you       will      become           a   great  philanthropist
# 8          you       will     attract    cultured     and        artistic
# 9     although         it       feels        like       a          roller
# 10     happier       days         are  definitely   ahead             for
# 11         you        are       going          to    have               a
# 12         you       will        take           a  chance              in
# 13         you        may      attend           a   party           where
# 14         you       will      always     possess       a           charm
# 15           a        new      voyage        will    fill            your
# 16         you        are          on         the   verge              of
# 17           a   pleasant  experience          is   ahead           don't
# 18           a  thrilling        time          is      in            your
# 19           a      heavy      burden          is  lifted            with
# 20         you        are       going          to    have               a
# 21  everywhere        you      choose          to      go        friendly
# 22         you       will      become           a   great  philanthropist
# 23         you       will     attract    cultured     and        artistic
# 24    although         it       feels        like       a          roller
# 25     happier       days         are  definitely   ahead             for
# 26         you        are       going          to    have               a
# 27         you       will        take           a  chance              in
# 28         you        may      attend           a   party           where
# 29         you       will      always     possess       a           charm
#
#            6            7        8         9       10        11      12
# 0        life         with   untold  memories    None      None    None
# 1   something          big     None      None    None      None    None
# 2        pass           it       by      None    None      None    None
# 3   immediate       future     None      None    None      None    None
# 4           a        phone  message        or  letter      None    None
# 5    pleasant   experience     None      None    None      None    None
# 6       faces         will    greet       you    None      None    None
# 7          in         your    later     years    None      None    None
# 8      people           to     your      home    None      None    None
# 9     coaster          now     life      will    calm      down    None
# 10        you     struggle      has     ended    None      None    None
# 11       very  comfortable      old       age    None      None    None
# 12  something           in      the      near  future      None    None
# 13    strange      customs  prevail      None    None      None    None
# 14        and        sense       of     humor    that  attracts  others
# 15       life         with   untold  memories    None      None    None
# 16  something          big     None      None    None      None    None
# 17       pass           it       by      None    None      None    None
# 18  immediate       future     None      None    None      None    None
# 19          a        phone  message        or  letter      None    None
# 20   pleasant   experience     None      None    None      None    None
# 21      faces         will    greet       you    None      None    None
# 22         in         your    later     years    None      None    None
# 23     people           to     your      home    None      None    None
# 24    coaster          now     life      will    calm      down    None
# 25        you     struggle      has     ended    None      None    None
# 26       very  comfortable      old       age    None      None    None
# 27  something           in      the      near  future      None    None
# 28    strange      customs  prevail      None    None      None    None
# 29        and        sense       of     humor    that  attracts  others
