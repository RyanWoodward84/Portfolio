# %% [markdown]
# # Question 4: Implementing a Multinomial Naive Bayes Classifier

# %% [markdown]
# We need to implement the multinomial naive bayes training algorithm

# %% [markdown]
# 1) We need to extract the vocabulary from the traindata.txt

# %%
import pandas as pd

data = pd.read_csv('traindata.txt', sep='\t', header = None)
data.head()
# Out:
#                                                    0
# 0  a new voyage will fill your life with untold m...
# 1              you are on the verge of something big
# 2    a pleasant experience is ahead don't pass it by
# 3       a thrilling time is in your immediate future
# 4  a heavy burden is lifted with a phone message ...

# %%
trainingData = []

# %%
for i in range(len(data)):
    test = data.iloc[i,0]
    trainingData.append(test.split())

trainingData
# Out:
# [['a',
#   'new',
#   'voyage',
#   'will',
#   'fill',
#   'your',
#   'life',
#   'with',
#   'untold',
#   'memories'],
#  ['you', 'are', 'on', 'the', 'verge', 'of', 'something', 'big'],
#  ['a', 'pleasant', 'experience', 'is', 'ahead', "don't", 'pass', 'it', 'by'],
#  ['a', 'thrilling', 'time', 'is', 'in', 'your', 'immediate', 'future'],
#  ['a',
#   'heavy',
#   'burden',
#   'is',
#   'lifted',
#   'with',
#   'a',
#   'phone',
#   'message',
#   'or',
#   'letter'],
#  ['you', 'are', 'going', 'to', 'have', 'a', 'pleasant', 'experience'],
#  ['everywhere',
#   'you',
#   'choose',
#   'to',
#   'go',
#   'friendly',
#   'faces',
#   'will',
#   'greet',
#   'you'],
#  ['you',
#   'will',
#   'become',
#   'a',
#   'great',
#   'philanthropist',
#   'in',
#   'your',
#   'later',
#   'years'],
#  ['you',
#   'will',
#   'attract',
#   'cultured',
#   'and',
#   'artistic',
#   'people',
#   'to',
#   'your',
#   'home'],
#  ['although',
#   'it',
#   'feels',
#   'like',
# ...

# %%
data = pd.DataFrame(trainingData)
data
# Out:
#              0          1           2       3          4      5          6  \
# 0            a        new      voyage    will       fill   your       life
# 1          you        are          on     the      verge     of  something
# 2            a   pleasant  experience      is      ahead  don't       pass
# 3            a  thrilling        time      is         in   your  immediate
# 4            a      heavy      burden      is     lifted   with          a
# ..         ...        ...         ...     ...        ...    ...        ...
# 317        the       only        good      is  knowledge    and        the
# 318        the      world          is  always      ready     to    receive
# 319        the    richest      person      is        the    one        who
# 320        get       away        from    home     awhile     to    restore
# 321  including     others          in    your       life   will      bring
#
#           7         8          9      10    11    12    13    14
# ...

# %%
labels = pd.read_csv('trainlabels.txt', sep='\t', header = None)
labels
# Out:
#      0
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# ..  ..
# 317  0
# 318  0
# 319  0
# 320  0
# 321  0
#
# [322 rows x 1 columns]

# %%
labels.columns = ['class']
pd.concat([data, labels], axis=1)
# Out:
#              0          1           2       3          4      5          6  \
# 0            a        new      voyage    will       fill   your       life
# 1          you        are          on     the      verge     of  something
# 2            a   pleasant  experience      is      ahead  don't       pass
# 3            a  thrilling        time      is         in   your  immediate
# 4            a      heavy      burden      is     lifted   with          a
# ..         ...        ...         ...     ...        ...    ...        ...
# 317        the       only        good      is  knowledge    and        the
# 318        the      world          is  always      ready     to    receive
# 319        the    richest      person      is        the    one        who
# 320        get       away        from    home     awhile     to    restore
# 321  including     others          in    your       life   will      bring
#
# ...

# %%
#Training data
train_data = open('20news-bydate/matlab/train.data')
df = pd.read_csv(train_data, delimiter=' ', names=['docIdx', 'wordIdx', 'count'])

#Training label
label = []
train_label = open('/home/sadat/Downloads/HW2_210/20news-bydate/matlab/train.label')
lines = train_label.readlines()
for line in lines:
    label.append(int(line.split()[0]))

#Increase label length to match docIdx
docIdx = df['docIdx'].values
i = 0
new_label = []
for index in range(len(docIdx)-1):
    new_label.append(label[i])
    if docIdx[index] != docIdx[index+1]:
        i += 1
new_label.append(label[i]) #for-loop ignores last value

#Add label column
df['classIdx'] = new_label

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-a78f2e0e4b0d> in <module>
#       1 #Training data
# ----> 2 train_data = open('20news-bydate/matlab/train.data')
#       3 df = pd.read_csv(train_data, delimiter=' ', names=['docIdx', 'wordIdx', 'count'])
#       4
#       5 #Training label
#
# FileNotFoundError: [Errno 2] No such file or directory: '20news-bydate/matlab/train.data'
